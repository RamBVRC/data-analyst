# %% [markdown]
# # Task 5: Python Basics – Data Cleaning using Pandas

# %% [markdown]
# ## Objective
# To load a dataset, identify missing values, clean the data using pandas, and save a cleaned dataset for further analysis.

# %% [markdown]
# ## Dataset Used
# - Titanic Dataset
# - Source: Kaggle
# - Rows cleaned and prepared for analysis

# %% [markdown]
# ## Data Cleaning Notes
# 1. Dataset was loaded using `pandas.read_csv()`.
# 2. Initial inspection was done using `head()` and `info()`.
# 3. Missing values were identified using `isnull().sum()`.
# 4. Age column missing values were filled using the median.
# 5. Duplicate rows were checked and removed.
# 6. Datatypes were verified for correct analysis.
# 7. Cleaned data was validated before saving.
# 8. Final cleaned dataset was saved as CSV for reuse.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('cleaned_data.csv')

df.head()

# %%
# Dataset information
df.info()

# %%
# Check missing values
df.isnull().sum()

# %%
# Check duplicates
df.duplicated().sum()

# %%
# Final cleaned dataset
df
